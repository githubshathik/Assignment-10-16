# %% [markdown]
# <a href="https://colab.research.google.com/github/githubshathik/Assignment-10-16/blob/shathik/DataPreprocessing_Assignment11_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Advance programming and Master data science
#
# Assignment 11:DataPreProcessing
#
# Name:Mohamed Shathik
#
# Batch:D10(B)
#
# Dept:Data Science
#
# mail id:mohamedshafa17@gmail.com

# %% [markdown]
# **Step 1: Importing the libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Step 2: Importing dataset**

# %%
data=pd.read_csv('/content/Data.csv')
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data.shape
# Out:
# (10, 4)

# %%
data.describe().T
# Out:
#         count          mean           std  ...      50%      75%      max
# Age       9.0     38.777778      7.693793  ...     38.0     44.0     50.0
# Salary    9.0  63777.777778  12265.579662  ...  61000.0  72000.0  83000.0
#
# [2 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    10 non-null     object
#  1   Age        9 non-null      float64
#  2   Salary     9 non-null      float64
#  3   Purchased  10 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 448.0+ bytes

# %% [markdown]
# **Step 3: Handling the missing data**

# %%
data.isnull().sum()
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
data['Salary'].fillna(data['Salary'].median(),inplace=True)

# %%
data['Age'].fillna(data['Age'].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Country      0
# Age          0
# Salary       0
# Purchased    0
# dtype: int64

# %% [markdown]
# **Step 4: Encoding categorical data**

# %%
from sklearn import preprocessing 

data["Purchased"]=data[["Purchased"]].apply(preprocessing.LabelEncoder().fit_transform)

# %%
data
# Out:
#    Country   Age   Salary  Purchased
# 0   France  44.0  72000.0          0
# 1    Spain  27.0  48000.0          1
# 2  Germany  30.0  54000.0          0
# 3    Spain  38.0  61000.0          0
# 4  Germany  40.0  61000.0          1
# 5   France  35.0  58000.0          1
# 6    Spain  38.0  52000.0          0
# 7   France  48.0  79000.0          1
# 8  Germany  50.0  83000.0          0
# 9   France  37.0  67000.0          1

# %% [markdown]
# **Step 5: Creating a dummy variable**

# %%
onehotencode=pd.get_dummies(data)
onehotencode
# Out:
#     Age   Salary  Purchased  Country_France  Country_Germany  Country_Spain
# 0  44.0  72000.0          0               1                0              0
# 1  27.0  48000.0          1               0                0              1
# 2  30.0  54000.0          0               0                1              0
# 3  38.0  61000.0          0               0                0              1
# 4  40.0  61000.0          1               0                1              0
# 5  35.0  58000.0          1               1                0              0
# 6  38.0  52000.0          0               0                0              1
# 7  48.0  79000.0          1               1                0              0
# 8  50.0  83000.0          0               0                1              0
# 9  37.0  67000.0          1               1                0              0

# %%
X=onehotencode.drop(columns=["Salary"])
X
# Out:
#     Age  Purchased  Country_France  Country_Germany  Country_Spain
# 0  44.0          0               1                0              0
# 1  27.0          1               0                0              1
# 2  30.0          0               0                1              0
# 3  38.0          0               0                0              1
# 4  40.0          1               0                1              0
# 5  35.0          1               1                0              0
# 6  38.0          0               0                0              1
# 7  48.0          1               1                0              0
# 8  50.0          0               0                1              0
# 9  37.0          1               1                0              0

# %%
Y=onehotencode["Salary"]
Y
# Out:
# 0    72000.0
# 1    48000.0
# 2    54000.0
# 3    61000.0
# 4    61000.0
# 5    58000.0
# 6    52000.0
# 7    79000.0
# 8    83000.0
# 9    67000.0
# Name: Salary, dtype: float64

# %% [markdown]
# **Step 6: Splitting the datasets into training sets and Test sets**

# %%
# Input Data
# X = features

# Output Data
# Y = MEDV


# splitting data to training and testing dataset.

#from sklearn.cross_validation import train_test_split
#the submodule cross_validation is renamed and reprecated to model_selection
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size =0.2,random_state = 5)

print("xtrain shape : ", X_train.shape)
print("xtest shape : ", X_test.shape)
print("ytrain shape : ", Y_train.shape)
print("ytest shape : ", Y_test.shape)
# Out:
# xtrain shape :  (8, 5)
# xtest shape :  (2, 5)
# ytrain shape :  (8,)
# ytest shape :  (2,)

# %% [markdown]
# **Step 7: Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler ## standrard scalig 
scaler = StandardScaler() #initialise to a variable
X_train_scaled = scaler.fit_transform(X_train) # fit (mean, sd) and then transform the training data
X_test_scaled = scaler.transform(X_test) # transform the test data
